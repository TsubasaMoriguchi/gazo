# %% [markdown]
# <a href="https://colab.research.google.com/github/TsubasaMoriguchi/gazo/blob/master/%E7%94%BB%E5%83%8F%E5%89%8D%E5%87%A6%E7%90%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/My Drive/gazo/face')

import ic_module as ic

import importlib
importlib.reload(ic)

import os.path as op

i = 0
for filename in ic.FileNames :
    # ディレクトリ名入力
    while True :
        dirname = input(">>「" + ic.ClassNames[i] + "」の画像のあるディレクトリ ： ")
        if op.isdir(dirname) :
            break
        print(">> そのディレクトリは存在しません！")

    # 関数実行
    ic.PreProcess(dirname, filename, var_amount=3)
    i += 1
# Out:
# >>「小松菜奈」の画像のあるディレクトリ ： /content/drive/My Drive/gazo/face/小松菜奈
# >> /content/drive/My Drive/gazo/face/小松菜奈から41個のファイル読み込み成功
# >>「CR7」の画像のあるディレクトリ ： /content/drive/My Drive/gazo/face/CR7
# >> /content/drive/My Drive/gazo/face/CR7から52個のファイル読み込み成功
# >>「久保建英」の画像のあるディレクトリ ： /content/drive/My Drive/gazo/face/久保建英
# >> /content/drive/My Drive/gazo/face/久保建英から32個のファイル読み込み成功

# %% [markdown]
# ## 学習

# %%
import ic_module as ic

# 関数実行
ic.Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (125, 32, 32, 3)
# >> 学習開始
# Epoch 1/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8280 - accuracy: 0.6250
# Epoch 00001: val_loss improved from inf to 1.48133, saving model to best.hdf5
# 5/5 [==============================] - 1s 115ms/step - loss: 1.0164 - accuracy: 0.6000 - val_loss: 1.4813 - val_accuracy: 0.3333
# Epoch 2/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8548 - accuracy: 0.6562
# Epoch 00002: val_loss improved from 1.48133 to 1.12196, saving model to best.hdf5
# 5/5 [==============================] - 0s 82ms/step - loss: 0.8429 - accuracy: 0.6286 - val_loss: 1.1220 - val_accuracy: 0.3333
# Epoch 3/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.8050 - accuracy: 0.5938
# Epoch 00003: val_loss did not improve from 1.12196
# 5/5 [==============================] - 0s 77ms/step - loss: 0.7822 - accuracy: 0.6286 - val_loss: 1.1455 - val_accuracy: 0.3333
# Epoch 4/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6692 - accuracy: 0.7188
# Epoch 00004: val_loss did not improve from 1.12196
# 5/5 [==============================] - 0s 74ms/step - loss: 0.6582 - accuracy: 0.7143 - val_loss: 1.3192 - val_accuracy: 0.3333
# Epoch 5/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7526 - accuracy: 0.6562
# Epoch 00005: val_loss did not improve from 1.12196
# 5/5 [==============================] - 0s 75ms/step - loss: 0.8482 - accuracy: 0.6286 - val_loss: 1.3082 - val_accuracy: 0.3333
# Epoch 6/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7113 - accuracy: 0.7188
# Epoch 00006: val_loss did not improve from 1.12196
# 5/5 [==============================] - 0s 73ms/step - loss: 0.7110 - accuracy: 0.6857 - val_loss: 1.1427 - val_accuracy: 0.3556
# Epoch 7/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7810 - accuracy: 0.6875
# Epoch 00007: val_loss did not improve from 1.12196
# 5/5 [==============================] - 0s 77ms/step - loss: 0.7605 - accuracy: 0.7143 - val_loss: 1.1278 - val_accuracy: 0.3556
# Epoch 8/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.7133 - accuracy: 0.6875
# Epoch 00008: val_loss did not improve from 1.12196
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6976 - accuracy: 0.6857 - val_loss: 1.1232 - val_accuracy: 0.3556
# Epoch 9/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6572 - accuracy: 0.7500
# Epoch 00009: val_loss improved from 1.12196 to 1.12168, saving model to best.hdf5
# 5/5 [==============================] - 0s 88ms/step - loss: 0.6958 - accuracy: 0.7143 - val_loss: 1.1217 - val_accuracy: 0.4556
# Epoch 10/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.6456 - accuracy: 0.7500
# Epoch 00010: val_loss improved from 1.12168 to 1.09883, saving model to best.hdf5
# 5/5 [==============================] - 0s 84ms/step - loss: 0.6271 - accuracy: 0.7714 - val_loss: 1.0988 - val_accuracy: 0.5667
# Epoch 11/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.5891 - accuracy: 0.8125
# Epoch 00011: val_loss did not improve from 1.09883
# 5/5 [==============================] - 0s 76ms/step - loss: 0.5763 - accuracy: 0.8286 - val_loss: 1.1163 - val_accuracy: 0.5667
# Epoch 12/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4245 - accuracy: 0.8438
# Epoch 00012: val_loss did not improve from 1.09883
# 5/5 [==============================] - 0s 78ms/step - loss: 0.5153 - accuracy: 0.8286 - val_loss: 1.1808 - val_accuracy: 0.5667
# Epoch 13/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.5487 - accuracy: 0.8438
# Epoch 00013: val_loss improved from 1.09883 to 1.07431, saving model to best.hdf5
# 5/5 [==============================] - 0s 86ms/step - loss: 0.5271 - accuracy: 0.8571 - val_loss: 1.0743 - val_accuracy: 0.5667
# Epoch 14/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4405 - accuracy: 0.9062
# Epoch 00014: val_loss did not improve from 1.07431
# 5/5 [==============================] - 0s 87ms/step - loss: 0.4872 - accuracy: 0.8857 - val_loss: 1.0838 - val_accuracy: 0.5667
# Epoch 15/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4351 - accuracy: 0.8750
# Epoch 00015: val_loss improved from 1.07431 to 1.03128, saving model to best.hdf5
# 5/5 [==============================] - 0s 93ms/step - loss: 0.4459 - accuracy: 0.8571 - val_loss: 1.0313 - val_accuracy: 0.6000
# Epoch 16/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.3697 - accuracy: 0.9375
# Epoch 00016: val_loss improved from 1.03128 to 1.02285, saving model to best.hdf5
# 5/5 [==============================] - 1s 101ms/step - loss: 0.3525 - accuracy: 0.9429 - val_loss: 1.0229 - val_accuracy: 0.6111
# Epoch 17/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4304 - accuracy: 0.8750
# Epoch 00017: val_loss did not improve from 1.02285
# 5/5 [==============================] - 0s 83ms/step - loss: 0.4054 - accuracy: 0.8857 - val_loss: 1.0385 - val_accuracy: 0.6111
# Epoch 18/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.3675 - accuracy: 0.9375
# Epoch 00018: val_loss did not improve from 1.02285
# 5/5 [==============================] - 0s 81ms/step - loss: 0.3468 - accuracy: 0.9429 - val_loss: 1.0715 - val_accuracy: 0.6111
# Epoch 19/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.3467 - accuracy: 0.9062
# Epoch 00019: val_loss did not improve from 1.02285
# 5/5 [==============================] - 0s 80ms/step - loss: 0.3283 - accuracy: 0.9143 - val_loss: 1.1025 - val_accuracy: 0.6000
# Epoch 20/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2884 - accuracy: 0.9375
# Epoch 00020: val_loss did not improve from 1.02285
# 5/5 [==============================] - 0s 89ms/step - loss: 0.2683 - accuracy: 0.9429 - val_loss: 1.1526 - val_accuracy: 0.5889
# Epoch 21/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.4327 - accuracy: 0.9062
# Epoch 00021: val_loss did not improve from 1.02285
# 5/5 [==============================] - 0s 78ms/step - loss: 0.4045 - accuracy: 0.9143 - val_loss: 1.1018 - val_accuracy: 0.6000
# Epoch 22/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.1831 - accuracy: 0.9688
# Epoch 00022: val_loss did not improve from 1.02285
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2333 - accuracy: 0.9429 - val_loss: 1.0986 - val_accuracy: 0.6000
# Epoch 23/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0
50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2542 - accuracy: 0.9375
# Epoch 00043: val_loss did not improve from 1.01342
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2372 - accuracy: 0.9429 - val_loss: 1.0796 - val_accuracy: 0.6111
# Epoch 44/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2094 - accuracy: 0.9375
# Epoch 00044: val_loss did not improve from 1.01342
# 5/5 [==============================] - 0s 77ms/step - loss: 0.2018 - accuracy: 0.9429 - val_loss: 1.0817 - val_accuracy: 0.6111
# Epoch 45/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2433 - accuracy: 0.9375
# Epoch 00045: val_loss did not improve from 1.01342
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2238 - accuracy: 0.9429 - val_loss: 1.0830 - val_accuracy: 0.6111
# Epoch 46/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2741 - accuracy: 0.9375
# Epoch 00046: val_loss did not improve from 1.01342
# 5/5 [==============================] - 0s 73ms/step - loss: 0.2553 - accuracy: 0.9429 - val_loss: 1.0817 - val_accuracy: 0.6111
# Epoch 47/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2211 - accuracy: 0.9062
# Epoch 00047: val_loss did not improve from 1.01342
# 5/5 [==============================] - 0s 80ms/step - loss: 0.2278 - accuracy: 0.9143 - val_loss: 1.0824 - val_accuracy: 0.6111
# Epoch 48/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.1612 - accuracy: 0.9375
# Epoch 00048: val_loss did not improve from 1.01342
# 5/5 [==============================] - 0s 73ms/step - loss: 0.1539 - accuracy: 0.9429 - val_loss: 1.0816 - val_accuracy: 0.6111
# Epoch 49/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2015 - accuracy: 0.9688
# Epoch 00049: val_loss did not improve from 1.01342
# 5/5 [==============================] - 0s 74ms/step - loss: 0.2673 - accuracy: 0.9429 - val_loss: 1.0818 - val_accuracy: 0.6111
# Epoch 50/50
# 4/5 [=======================>......] - ETA: 0s - loss: 0.2923 - accuracy: 0.9375
# Epoch 00050: val_loss did not improve from 1.01342
# 5/5 [==============================] - 0s 75ms/step - loss: 0.2689 - accuracy: 0.9429 - val_loss: 1.0775 - val_accuracy: 0.6111

# %% [markdown]
# ## 試行・実験

# %%
import ic_module as ic
import os.path as op

while True:
    while True:
        imgname = input("\n>> 入力したい画像ファイル(「END」で終了) ： ")
        if op.isfile(imgname) or imgname == "END":
            break
        print(">> そのファイルは存在しません！")
    if imgname == "END":
        break

    # 関数実行
    ic.TestProcess(imgname)
# Out:
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test
# >> そのファイルは存在しません！
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_0.jpg
# 1
# 2
# 3
# >> 計算結果↓
# [[0.9659305  0.02590892 0.00816054]]
# >> この画像は「小松菜奈」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_24.jpg
# 1
# 2
# 3
# >> 計算結果↓
# [[0.05420639 0.83065087 0.11514269]]
# >> この画像は「CR7」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_45.jpg
# 1
# 2
# 3
# >> 計算結果↓
# [[0.00121562 0.9906997  0.00808472]]
# >> この画像は「CR7」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_58.jpg
# 1
# 2
# 3
# >> 計算結果↓
# [[0.65064186 0.29156578 0.0577924 ]]
# >> この画像は「小松菜奈」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_65.jpg
# 1
# 2
# 3
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e36e656a8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.24234958 0.59934753 0.15830287]]
# >> この画像は「CR7」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_67.jpg
# 1
# 2
# 3
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e36e65c80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.2622476  0.6287469  0.10900549]]
# >> この画像は「CR7」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_66.jpg
# 1
# 2
# 3
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e36d6c378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.24836531 0.6309592  0.12067546]]
# >> この画像は「CR7」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_66.jpg
# 1
# 2
# 3
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e36e65510> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.24836531 0.6309592  0.12067546]]
# >> この画像は「CR7」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_66.jpg
# 1
# 2
# 3
# WARNING:tensorflow:9 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e36c51400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.24836531 0.6309592  0.12067546]]
# >> この画像は「CR7」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_57.jpg
# 1
# 2
# 3
# WARNING:tensorflow:10 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e36bcba60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.7446352  0.1866067  0.06875803]]
# >> この画像は「小松菜奈」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： /content/drive/My Drive/gazo/face/test/image_52.jpg
# 1
# 2
# 3
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8e36b6ad08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# >> 計算結果↓
# [[0.8223081  0.1110929  0.06659886]]
# >> この画像は「小松菜奈」です。
#
# >> 入力したい画像ファイル(「END」で終了) ： END
